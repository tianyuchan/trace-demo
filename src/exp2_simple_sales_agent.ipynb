# %% [markdown]
# # A Simple Sales Agent
# https://github.com/microsoft/Trace

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from opto import trace

@trace.model
class Agent:

    def __init__(self, system_prompt):
        self.system_prompt = system_prompt
        self.instruct1 = trace.node("Decide the language", trainable=True)
        self.instruct2 = trace.node("Extract name if it's there", trainable=True)

    def __call__(self, user_query):
        language = trace.operators.call_llm(self.system_prompt,
                                            user_query, self.instruct1)
        en_or_es = self.decide_lang(language)

        user_name = trace.operators.call_llm(self.system_prompt,
                                             user_query, self.instruct2)
        greeting = self.greet(en_or_es, user_name)

        return greeting

    @trace.bundle(trainable=True)
    def decide_lang(self, response):
        """Map the language into a variable"""
        return

    @trace.bundle(trainable=True)
    def greet(self, lang, user_name):
        """Produce a greeting based on the language"""
        greeting = ""
        return f"{greeting}, {user_name}!"

# %%
from opto.optimizers import OptoPrime

def feedback_fn(generated_response, gold_label='en'):
    if  gold_label == 'en' and 'Hello' in generated_response:
        return "Correct"
    elif gold_label == 'cn' and '你好，Xiaoming' == generated_response:
        return "Correct"
    else:
        return "Incorrect"

def train():
    epoch = 5
    agent = Agent("You are a sales assistant.")
    optimizer = OptoPrime(agent.parameters())

    for i in range(epoch):
        print(f"Training Epoch {i}")
        try:
            greeting = agent("Xiaoming is a customer from China.")
            feedback = feedback_fn(greeting.data, 'cn')
        except trace.ExecutionError as e:
            greeting = e.exception_node
            feedback, terminal, reward = greeting.data, False, 0

        optimizer.zero_feedback()
        optimizer.backward(greeting, feedback)
        optimizer.step(verbose=True)

        if feedback == 'Correct':
            break

    return agent

agent = train()
# Out:
# Using CustomLLM as the default LLM backend.
# Training Epoch 0
# Prompt
#
# You're tasked to solve a coding/algorithm problem. You will see the instruction, the code, the documentation of each function used in the code, and the feedback about the execution result.
#
# Specifically, a problem will be composed of the following parts:
# - #Instruction: the instruction which describes the things you need to do or the question you should answer.
# - #Code: the code defined in the problem.
# - #Documentation: the documentation of each function used in #Code. The explanation might be incomplete and just contain high-level description. You can use the values in #Others to help infer how those functions work.
# - #Variables: the input variables that you can change.
# - #Constraints: the constraints or descriptions of the variables in #Variables.
# - #Inputs: the values of other inputs to the code, which are not changeable.
# - #Others: the intermediate values created through the code execution.
# - #Outputs: the result of the code output.
# - #Feedback: the feedback about the code's execution result.
#
# In #Variables, #Inputs, #Outputs, and #Others, the format is:
#
# <data_type> <variable_name> = <value>
#
# If <type> is (code), it means <value> is the source code of a python code, which may include docstring and definitions.
#
# Output_format: Your output should be in the following json format, satisfying the json syntax:
#
# {{
# "reasoning": <Your reasoning>,
# "answer": <Your answer>,
# "suggestion": {{
#     <variable_1>: <suggested_value_1>,
#     <variable_2>: <suggested_value_2>,
# }}
# }}
#
# In "reasoning", explain the problem: 1. what the #Instruction means 2. what the #Feedback on #Output means to #Variables considering how #Variables are used in #Code and other values in #Documentation, #Inputs, #Others. 3. Reasoning about the suggested changes in #Variables (if needed) and the expected result.
#
# If #Instruction asks for an answer, write it down in "answer".
#
# If you need to suggest a change in the values of #Variables, write down the suggested values in "suggestion". Remember you can change only the values in #Variables, not others. When <type> of a variable is (code), you should write the new definition in the format of python code without syntax errors, and you should not change the function name or the function signature.
#
# If no changes or answer are needed, just output TERMINATE.
#
# Now you see problem instance:
#
# ================================
#
# #Instruction
# You need to change the <value> of the variables in #Variables to improve the output in accordance to #Feedback.
#
# #Code
# call_llm0 = call_llm(system_prompt=system_prompt0, args_0=str2, args_1=str0)
# call_llm1 = call_llm(system_prompt=system_prompt1, args_0=str3, args_1=str1)
# eval0 = eval(self=ModelWrapper0, response=call_llm0, __code=__code2)
# eval1 = eval(self=ModelWrapper0, lang=eval0, user_name=call_llm1, __code=__code4)
#
# #Documentation
# [call_llm] Query the language model of system_prompt with user_prompts..
# [eval] This operator eval(__code, *args, **kwargs) evaluates the code block, where __code is the code (str) and *args and **kwargs are the arguments of the function. The output is the result of the evaluation, i.e., __code(*args, **kwargs).
#
# #Variables
# (str) str0=Decide the language
# (str) str1=Extract name if it's there
# (code) __code2:def decide_lang(self, response):
#         """Map the language into a variable"""
#         return
# (code) __code4:def greet(self, lang, user_name):
#         """Produce a greeting based on the language"""
#         greeting = ""
#         return f"{greeting}, {user_name}!"
#
# #Constraints
# (code) __code2: The code should start with:
# def decide_lang(self, response):
#         """Map the language into a variable"""
# (code) __code4: The code should start with:
# def greet(self, lang, user_name):
#         """Produce a greeting based on the language"""
#
# #Inputs
# (str) system_prompt0=You are a sales assistant.
# (str) str2=Xiaoming is a customer from China.
# (ModelWrapper) ModelWrapper0=<opto.trace.modules.model.<locals>.ModelWrapper object at 0x1042c12e0>
# (str) system_prompt1=You are a sales assistant.
# (str) str3=Xiaoming is a customer from China.
#
# #Others
# (str) call_llm0=Since Xiaoming is from China, it would be ideal to communicate in Chinese (Mandarin), unless Xiaoming prefers another language or has specified otherwise. If you’d like, I can assist you in either English or Mandarin. Let me know your preference!
# (NoneType) eval0=None
# (str) call_llm1=The name extracted is: Xiaoming
#
# #Outputs
# (str) eval1=, The name extracted is: Xiaoming!
#
# #Feedback
# Incorrect
#
# ================================
#
#
# Your response:
#
# LLM response:
#  {
#   "reasoning": "The #Feedback indicates that the output in #Outputs is incorrect. Given that 'eval1' combines a greeting with the username extracted from 'call_llm1', it appears that the variable '__code4' does not properly implement a greeting in the returned string. Additionally, '__code2' does not implement functionality to map a language to a variable, and 'eval0' outputs 'None' instead of a valid language. These issues stem from incomplete code definitions in '__code2' and '__code4'. By updating these definitions, the logic can correctly decide a language and produce a proper greeting. The changes must align with the constraints for these variables to ensure correctness.",
#   "answer": null,
#   "suggestion": {
#     "__code2": "def decide_lang(self, response):\n    \"\"\"Map the language into a variable\"\"\"\n    if 'Chinese' in response or 'Mandarin' in response:\n        return 'Mandarin'\n    elif 'English' in response:\n        return 'English'\n    else:\n        return 'Unknown'",
#     "__code4": "def greet(self, lang, user_name):\n    \"\"\"Produce a greeting based on the language\"\"\"\n    greeting = \"Hello\" if lang == 'English' else \"你好\" if lang == 'Mandarin' else \"Hi\"\n    return f\"{greeting}, {user_name}!\""
#   }
# }
# Training Epoch 1
# Prompt
#
# You're tasked to solve a coding/algorithm problem. You will see the instruction, the code, the documentation of each function used in the code, and the feedback about the execution result.
#
# Specifically, a problem will be composed of the following parts:
# - #Instruction: the instruction which describes the things you need to do or the question you should answer.
# - #Code: the code defined in the problem.
# - #Documentation: the documentation of each function used in #Code. The explanation might be incomplete and just contain high-level description. You can use the values in #Others to help infer how those functions work.
# - #Variables: the input variables that you can change.
# - #Constraints: the constraints or descriptions of the variables in #Variables.
# - #Inputs: the values of other inputs to the code, which are not changeable.
# - #Others: the intermediate values created through the code execution.
# - #Outputs: the result of the code output.
# - #Feedback: the feedback about the code's execution result.
#
# In #Variables, #Inputs, #Outputs, and #Others, the format is:
#
# <data_type> <variable_name> = <value>
#
# If <type> is (code), it means <value> is the source code of a python code, which may include docstring and definitions.
#
# Output_format: Your output should be in the following json format, satisfying the json syntax:
#
# {{
# "reasoning": <Your reasoning>,
# "answer": <Your answer>,
# "suggestion": {{
#     <variable_1>: <suggested_value_1>,
#     <variable_2>: <suggested_value_2>,
# }}
# }}
#
# In "reasoning", explain the problem: 1. what the #Instruction means 2. what the #Feedback on #Output means to #Variables considering how #Variables are used in #Code and other values in #Documentation, #Inputs, #Others. 3. Reasoning about the suggested changes in #Variables (if needed) and the expected result.
#
# If #Instruction asks for an answer, write it down in "answer".
#
# If you need to suggest a change in the values of #Variables, write down the suggested values in "suggestion". Remember you can change only the values in #Variables, not others. When <type> of a variable is (code), you should write the new definition in the format of python code without syntax errors, and you should not change the function name or the function signature.
#
# If no changes or answer are needed, just output TERMINATE.
#
# Now you see problem instance:
#
# ================================
#
# #Instruction
# You need to change the <value> of the variables in #Variables to improve the output in accordance to #Feedback.
#
# #Code
# call_llm2 = call_llm(system_prompt=system_prompt2, args_0=str5, args_1=str0)
# call_llm3 = call_llm(system_prompt=system_prompt3, args_0=str6, args_1=str1)
# eval2 = eval(self=ModelWrapper0, response=call_llm2, __code=__code2)
# eval3 = eval(self=ModelWrapper0, lang=eval2, user_name=call_llm3, __code=__code4)
#
# #Documentation
# [call_llm] Query the language model of system_prompt with user_prompts..
# [eval] This operator eval(__code, *args, **kwargs) evaluates the code block, where __code is the code (str) and *args and **kwargs are the arguments of the function. The output is the result of the evaluation, i.e., __code(*args, **kwargs).
#
# #Variables
# (str) str0=Decide the language
# (str) str1=Extract name if it's there
# (code) __code2:def decide_lang(self, response):
#     """Map the language into a variable"""
#     if "Chinese" in response or "Mandarin" in response:
#         return "Mandarin"
#     elif "English" in response:
#         return "English"
#     else:
#         return "Unknown"
#
# (code) __code4:def greet(self, lang, user_name):
#     """Produce a greeting based on the language"""
#     greeting = "Hello" if lang == "English" else "你好" if lang == "Mandarin" else "Hi"
#     return f"{greeting}, {user_name}!"
#
#
# #Constraints
# (code) __code2: The code should start with:
# def decide_lang(self, response):
#         """Map the language into a variable"""
# (code) __code4: The code should start with:
# def greet(self, lang, user_name):
#         """Produce a greeting based on the language"""
#
# #Inputs
# (str) system_prompt2=You are a sales assistant.
# (str) str5=Xiaoming is a customer from China.
# (ModelWrapper) ModelWrapper0=<opto.trace.modules.model.<locals>.ModelWrapper object at 0x1042c12e0>
# (str) system_prompt3=You are a sales assistant.
# (str) str6=Xiaoming is a customer from China.
#
# #Others
# (str) call_llm2=Since Xiaoming is from China, it would be best to communicate in **Mandarin Chinese** if Xiaoming prefers it. However, if Xiaoming is comfortable with English or another language, I can assist in that as well. You can confirm their language preference to ensure clear communication! 😊
# (str) eval2=Mandarin
# (str) call_llm3=The name provided is **Xiaoming**.
#
# #Outputs
# (str) eval3=你好, The name provided is **Xiaoming**.!
#
# #Feedback
# Incorrect
#
# ================================
#
#
# Your response:
#
# LLM response:
#  {
# "reasoning": "The instruction requests modifying the values of the variables in #Variables to improve the output based on the feedback that eval3 output is 'Incorrect'. The current value of eval3 ('你好, The name provided is **Xiaoming**.!') suggests that while the language evaluation and greeting appear correct, the format or content of 'eval3' might not align with expected output. From #Code, eval3 combines the language output (eval2) and name extracted (call_llm3) without properly formatting the user_name part extracted from call_llm3. The issue lies in not properly isolating the name part from the string call_llm3 ('The name provided is **Xiaoming**.') during eval3 construction. Suggestions to str1 will improve name extraction by call_llm3 so it matches expected format.",
# "answer": null,
# "suggestion": {
#     "str1": "Extract only the name provided"
# }
# }
# Training Epoch 2
# Prompt
#
# You're tasked to solve a coding/algorithm problem. You will see the instruction, the code, the documentation of each function used in the code, and the feedback about the execution result.
#
# Specifically, a problem will be composed of the following parts:
# - #Instruction: the instruction which describes the things you need to do or the question you should answer.
# - #Code: the code defined in the problem.
# - #Documentation: the documentation of each function used in #Code. The explanation might be incomplete and just contain high-level description. You can use the values in #Others to help infer how those functions work.
# - #Variables: the input variables that you can change.
# - #Constraints: the constraints or descriptions of the variables in #Variables.
# - #Inputs: the values of other inputs to the code, which are not changeable.
# - #Others: the intermediate values created through the code execution.
# - #Outputs: the result of the code output.
# - #Feedback: the feedback about the code's execution result.
#
# In #Variables, #Inputs, #Outputs, and #Others, the format is:
#
# <data_type> <variable_name> = <value>
#
# If <type> is (code), it means <value> is the source code of a python code, which may include docstring and definitions.
#
# Output_format: Your output should be in the following json format, satisfying the json syntax:
#
# {{
# "reasoning": <Your reasoning>,
# "answer": <Your answer>,
# "suggestion": {{
#     <variable_1>: <suggested_value_1>,
#     <variable_2>: <suggested_value_2>,
# }}
# }}
#
# In "reasoning", explain the problem: 1. what the #Instruction means 2. what the #Feedback on #Output means to #Variables considering how #Variables are used in #Code and other values in #Documentation, #Inputs, #Others. 3. Reasoning about the suggested changes in #Variables (if needed) and the expected result.
#
# If #Instruction asks for an answer, write it down in "answer".
#
# If you need to suggest a change in the values of #Variables, write down the suggested values in "suggestion". Remember you can change only the values in #Variables, not others. When <type> of a variable is (code), you should write the new definition in the format of python code without syntax errors, and you should not change the function name or the function signature.
#
# If no changes or answer are needed, just output TERMINATE.
#
# Now you see problem instance:
#
# ================================
#
# #Instruction
# You need to change the <value> of the variables in #Variables to improve the output in accordance to #Feedback.
#
# #Code
# call_llm4 = call_llm(system_prompt=system_prompt4, args_0=str8, args_1=str0)
# call_llm5 = call_llm(system_prompt=system_prompt5, args_0=str9, args_1=str1)
# eval4 = eval(self=ModelWrapper0, response=call_llm4, __code=__code2)
# eval5 = eval(self=ModelWrapper0, lang=eval4, user_name=call_llm5, __code=__code4)
#
# #Documentation
# [call_llm] Query the language model of system_prompt with user_prompts..
# [eval] This operator eval(__code, *args, **kwargs) evaluates the code block, where __code is the code (str) and *args and **kwargs are the arguments of the function. The output is the result of the evaluation, i.e., __code(*args, **kwargs).
#
# #Variables
# (str) str0=Decide the language
# (str) str1=Extract only the name provided
# (code) __code2:def decide_lang(self, response):
#     """Map the language into a variable"""
#     if "Chinese" in response or "Mandarin" in response:
#         return "Mandarin"
#     elif "English" in response:
#         return "English"
#     else:
#         return "Unknown"
#
# (code) __code4:def greet(self, lang, user_name):
#     """Produce a greeting based on the language"""
#     greeting = "Hello" if lang == "English" else "你好" if lang == "Mandarin" else "Hi"
#     return f"{greeting}, {user_name}!"
#
#
# #Constraints
# (code) __code2: The code should start with:
# def decide_lang(self, response):
#         """Map the language into a variable"""
# (code) __code4: The code should start with:
# def greet(self, lang, user_name):
#         """Produce a greeting based on the language"""
#
# #Inputs
# (str) system_prompt4=You are a sales assistant.
# (str) str8=Xiaoming is a customer from China.
# (ModelWrapper) ModelWrapper0=<opto.trace.modules.model.<locals>.ModelWrapper object at 0x1042c12e0>
# (str) system_prompt5=You are a sales assistant.
# (str) str9=Xiaoming is a customer from China.
#
# #Others
# (str) call_llm4=Since Xiaoming is a customer from China, it would be best to communicate in **Mandarin Chinese**, as it is the official and most widely spoken language in China. If Xiaoming prefers English or another language, we can adjust accordingly.
# (str) eval4=Mandarin
# (str) call_llm5=Xiaoming
#
# #Outputs
# (str) eval5=你好, Xiaoming!
#
# #Feedback
# Incorrect
#
# ================================
#
#
# Your response:
#
# LLM response:
#  {
# "reasoning": "The instruction requires improving the output based on the feedback that the output is 'Incorrect'. The output eval5 is supposed to be checked against the context of variables and the provided values. Looking at the execution of the code, `call_llm5` extracts 'Xiaoming', the name of the customer. The `decide_lang` function correctly identifies 'Mandarin' as the language, and the `greet` function produces a greeting based on the language and user_name parameters. The output '你好, Xiaoming!' appears correct for Mandarin, assuming the context of the problem. Since the feedback says 'Incorrect', it suggests that either the logic in `__code4` is problematic, or the function misinterpreted the requirements around language and greeting format. Specifically, the greeting might require additional customization or clarification to match what is deemed 'correct'. To improve the output, clarifying the language detection and greeting generation criteria, as well as adjusting for errors or misunderstandings in variable values, can help.",
# "answer": "The greeting '你好, Xiaoming!' matches with the Mandarin language detection. Based on feedback, the result needs adjustment.",
# "suggestion": {
#     "__code4": "def greet(self, lang, user_name):\n    \"\"\"Produce a greeting based on the language\"\"\"\n    if lang == \"Mandarin\":\n        greeting = \"您好\"  # Use a formal greeting format for Mandarin.\n    elif lang == \"English\":\n        greeting = \"Hello\"\n    else:\n        greeting = \"Hi\"\n    return f\"{greeting}, {user_name}!\""
# }
# }
# Training Epoch 3
# Prompt
#
# You're tasked to solve a coding/algorithm problem. You will see the instruction, the code, the documentation of each function used in the code, and the feedback about the execution result.
#
# Specifically, a problem will be composed of the following parts:
# - #Instruction: the instruction which describes the things you need to do or the question you should answer.
# - #Code: the code defined in the problem.
# - #Documentation: the documentation of each function used in #Code. The explanation might be incomplete and just contain high-level description. You can use the values in #Others to help infer how those functions work.
# - #Variables: the input variables that you can change.
# - #Constraints: the constraints or descriptions of the variables in #Variables.
# - #Inputs: the values of other inputs to the code, which are not changeable.
# - #Others: the intermediate values created through the code execution.
# - #Outputs: the result of the code output.
# - #Feedback: the feedback about the code's execution result.
#
# In #Variables, #Inputs, #Outputs, and #Others, the format is:
#
# <data_type> <variable_name> = <value>
#
# If <type> is (code), it means <value> is the source code of a python code, which may include docstring and definitions.
#
# Output_format: Your output should be in the following json format, satisfying the json syntax:
#
# {{
# "reasoning": <Your reasoning>,
# "answer": <Your answer>,
# "suggestion": {{
#     <variable_1>: <suggested_value_1>,
#     <variable_2>: <suggested_value_2>,
# }}
# }}
#
# In "reasoning", explain the problem: 1. what the #Instruction means 2. what the #Feedback on #Output means to #Variables considering how #Variables are used in #Code and other values in #Documentation, #Inputs, #Others. 3. Reasoning about the suggested changes in #Variables (if needed) and the expected result.
#
# If #Instruction asks for an answer, write it down in "answer".
#
# If you need to suggest a change in the values of #Variables, write down the suggested values in "suggestion". Remember you can change only the values in #Variables, not others. When <type> of a variable is (code), you should write the new definition in the format of python code without syntax errors, and you should not change the function name or the function signature.
#
# If no changes or answer are needed, just output TERMINATE.
#
# Now you see problem instance:
#
# ================================
#
# #Instruction
# You need to change the <value> of the variables in #Variables to improve the output in accordance to #Feedback.
#
# #Code
# call_llm6 = call_llm(system_prompt=system_prompt6, args_0=str11, args_1=str0)
# call_llm7 = call_llm(system_prompt=system_prompt7, args_0=str12, args_1=str1)
# eval6 = eval(self=ModelWrapper0, response=call_llm6, __code=__code2)
# eval7 = eval(self=ModelWrapper0, lang=eval6, user_name=call_llm7, __code=__code4)
#
# #Documentation
# [call_llm] Query the language model of system_prompt with user_prompts..
# [eval] This operator eval(__code, *args, **kwargs) evaluates the code block, where __code is the code (str) and *args and **kwargs are the arguments of the function. The output is the result of the evaluation, i.e., __code(*args, **kwargs).
#
# #Variables
# (str) str0=Decide the language
# (str) str1=Extract only the name provided
# (code) __code2:def decide_lang(self, response):
#     """Map the language into a variable"""
#     if "Chinese" in response or "Mandarin" in response:
#         return "Mandarin"
#     elif "English" in response:
#         return "English"
#     else:
#         return "Unknown"
#
# (code) __code4:def greet(self, lang, user_name):
#     """Produce a greeting based on the language"""
#     if lang == "Mandarin":
#         greeting = "您好"  # Use a formal greeting format for Mandarin.
#     elif lang == "English":
#         greeting = "Hello"
#     else:
#         greeting = "Hi"
#     return f"{greeting}, {user_name}!"
#
#
# #Constraints
# (code) __code2: The code should start with:
# def decide_lang(self, response):
#         """Map the language into a variable"""
# (code) __code4: The code should start with:
# def greet(self, lang, user_name):
#         """Produce a greeting based on the language"""
#
# #Inputs
# (str) system_prompt6=You are a sales assistant.
# (str) str11=Xiaoming is a customer from China.
# (ModelWrapper) ModelWrapper0=<opto.trace.modules.model.<locals>.ModelWrapper object at 0x1042c12e0>
# (str) system_prompt7=You are a sales assistant.
# (str) str12=Xiaoming is a customer from China.
#
# #Others
# (str) call_llm6=Since Xiaoming is from China, it is advisable to communicate with him in Mandarin Chinese, as that is the most widely spoken language in China. If Xiaoming prefers another language, you could confirm with him for clarity.
# (str) eval6=Mandarin
# (str) call_llm7=Xiaoming
#
# #Outputs
# (str) eval7=您好, Xiaoming!
#
# #Feedback
# Incorrect
#
# ================================
#
#
# Your response:
#
# LLM response:
#  {
# "reasoning": "The code processes the inputs through two language model calls and evaluations to decide the language and produce a greeting. The feedback indicates that the output eval7, which is '您好, Xiaoming!', is incorrect. Looking at the logic in the provided code, the issue may arise from the language detection or the final greeting. Since the language ('Mandarin') and the user_name ('Xiaoming') appear to be correctly extracted, and the greeting '您好' is also consistent with Mandarin, the issue seems unclear from the instance provided. However, it may lie in either the logic of `__code2` or `__code4`. To improve eval7, no changes in the input variables (str0, str1, __code2, __code4) are immediately obvious from the given context since the output technically matches expected behavior. Further clarification on what constitutes a 'correct' eval7 output would be necessary.",
# "answer": null,
# "suggestion": {}
# }
# Training Epoch 4
# Prompt
#
# You're tasked to solve a coding/algorithm problem. You will see the instruction, the code, the documentation of each function used in the code, and the feedback about the execution result.
#
# Specifically, a problem will be composed of the following parts:
# - #Instruction: the instruction which describes the things you need to do or the question you should answer.
# - #Code: the code defined in the problem.
# - #Documentation: the documentation of each function used in #Code. The explanation might be incomplete and just contain high-level description. You can use the values in #Others to help infer how those functions work.
# - #Variables: the input variables that you can change.
# - #Constraints: the constraints or descriptions of the variables in #Variables.
# - #Inputs: the values of other inputs to the code, which are not changeable.
# - #Others: the intermediate values created through the code execution.
# - #Outputs: the result of the code output.
# - #Feedback: the feedback about the code's execution result.
#
# In #Variables, #Inputs, #Outputs, and #Others, the format is:
#
# <data_type> <variable_name> = <value>
#
# If <type> is (code), it means <value> is the source code of a python code, which may include docstring and definitions.
#
# Output_format: Your output should be in the following json format, satisfying the json syntax:
#
# {{
# "reasoning": <Your reasoning>,
# "answer": <Your answer>,
# "suggestion": {{
#     <variable_1>: <suggested_value_1>,
#     <variable_2>: <suggested_value_2>,
# }}
# }}
#
# In "reasoning", explain the problem: 1. what the #Instruction means 2. what the #Feedback on #Output means to #Variables considering how #Variables are used in #Code and other values in #Documentation, #Inputs, #Others. 3. Reasoning about the suggested changes in #Variables (if needed) and the expected result.
#
# If #Instruction asks for an answer, write it down in "answer".
#
# If you need to suggest a change in the values of #Variables, write down the suggested values in "suggestion". Remember you can change only the values in #Variables, not others. When <type> of a variable is (code), you should write the new definition in the format of python code without syntax errors, and you should not change the function name or the function signature.
#
# If no changes or answer are needed, just output TERMINATE.
#
# Now you see problem instance:
#
# ================================
#
# #Instruction
# You need to change the <value> of the variables in #Variables to improve the output in accordance to #Feedback.
#
# #Code
# call_llm8 = call_llm(system_prompt=system_prompt8, args_0=str14, args_1=str0)
# call_llm9 = call_llm(system_prompt=system_prompt9, args_0=str15, args_1=str1)
# eval8 = eval(self=ModelWrapper0, response=call_llm8, __code=__code2)
# eval9 = eval(self=ModelWrapper0, lang=eval8, user_name=call_llm9, __code=__code4)
#
# #Documentation
# [call_llm] Query the language model of system_prompt with user_prompts..
# [eval] This operator eval(__code, *args, **kwargs) evaluates the code block, where __code is the code (str) and *args and **kwargs are the arguments of the function. The output is the result of the evaluation, i.e., __code(*args, **kwargs).
#
# #Variables
# (str) str0=Decide the language
# (str) str1=Extract only the name provided
# (code) __code2:def decide_lang(self, response):
#     """Map the language into a variable"""
#     if "Chinese" in response or "Mandarin" in response:
#         return "Mandarin"
#     elif "English" in response:
#         return "English"
#     else:
#         return "Unknown"
#
# (code) __code4:def greet(self, lang, user_name):
#     """Produce a greeting based on the language"""
#     if lang == "Mandarin":
#         greeting = "您好"  # Use a formal greeting format for Mandarin.
#     elif lang == "English":
#         greeting = "Hello"
#     else:
#         greeting = "Hi"
#     return f"{greeting}, {user_name}!"
#
#
# #Constraints
# (code) __code2: The code should start with:
# def decide_lang(self, response):
#         """Map the language into a variable"""
# (code) __code4: The code should start with:
# def greet(self, lang, user_name):
#         """Produce a greeting based on the language"""
#
# #Inputs
# (str) system_prompt8=You are a sales assistant.
# (str) str14=Xiaoming is a customer from China.
# (ModelWrapper) ModelWrapper0=<opto.trace.modules.model.<locals>.ModelWrapper object at 0x1042c12e0>
# (str) system_prompt9=You are a sales assistant.
# (str) str15=Xiaoming is a customer from China.
#
# #Others
# (str) call_llm8=Given that Xiaoming is from China, it would be appropriate to communicate in Mandarin Chinese if Xiaoming is a native speaker. However, if you’re unsure of their language preference, you can politely ask:
#
# "您好！请问您是否习惯用中文交流，或者是否更喜欢使用其他语言？"
# (Hello! Would you prefer communicating in Chinese, or do you prefer using another language?)
#
# This ensures the customer feels comfortable.
# (str) eval8=Mandarin
# (str) call_llm9=Xiaoming
#
# #Outputs
# (str) eval9=您好, Xiaoming!
#
# #Feedback
# Incorrect
#
# ================================
#
#
# Your response:
#
# LLM response:
#  {
# "reasoning": "The instruction indicates that the output needs to be improved to address the feedback that the result (eval9) is incorrect. Based on the feedback, we must ensure the variable values align better with the intended output. eval9 is the final output generated by the code, combining the results of eval8 (language determination) and call_llm9 (name extraction) passed to __code4 - the 'greet' function. Here, '您好, Xiaoming!' uses a Mandarin greeting, suggesting eval8 was correctly identified as 'Mandarin'. The name 'Xiaoming' is extracted correctly. However, the details in call_llm8 suggest a more dynamic evaluation may be needed, such as asking for language preferences dynamically. The issue may lie in the hardcoded handling of language determination or formality. Suggestions aim to ensure correctness by validating and improving these variables accordingly.",
# "answer": null,
# "suggestion": {
#     "__code2": "def decide_lang(self, response):\n    \"\"\"Map the language into a variable\"\"\"\n    if \"Chinese\" in response or \"Mandarin\" in response:\n        return \"Mandarin\"\n    elif \"English\" in response:\n        return \"English\"\n    elif \"Other\" in response:\n        return \"Ask\"  # Special handling for ambiguity.\n    else:\n        return \"Unknown\"",
#     "__code4": "def greet(self, lang, user_name):\n    \"\"\"Produce a greeting based on the language\"\"\"\n    if lang == \"Mandarin\":\n        greeting = \"您好\"  # Use a formal greeting format for Mandarin.\n    elif lang == \"English\":\n        greeting = \"Hello\"\n    elif lang == \"Ask\":\n        greeting = \"What language would you prefer?\"\n    else:\n        greeting = \"Hi\"\n    return f\"{greeting}, {user_name}!\""
# }
# }

# %%
print(agent("Xiaomi is a customer from China."))
# Out:
# MessageNode: (eval:11, dtype=<class 'str'>, data=您好, Xiaomi!)

# %%
for param in agent.parameters():
    print(f"Parameter: {param.name}\n {param.data}")
# Out:
# Parameter: __code:2
#  def decide_lang(self, response):
#     """Map the language into a variable"""
#     if "Chinese" in response or "Mandarin" in response:
#         return "Mandarin"
#     elif "English" in response:
#         return "English"
#     elif "Other" in response:
#         return "Ask"  # Special handling for ambiguity.
#     else:
#         return "Unknown"
#
# Parameter: __code:4
#  def greet(self, lang, user_name):
#     """Produce a greeting based on the language"""
#     if lang == "Mandarin":
#         greeting = "您好"  # Use a formal greeting format for Mandarin.
#     elif lang == "English":
#         greeting = "Hello"
#     elif lang == "Ask":
#         greeting = "What language would you prefer?"
#     else:
#         greeting = "Hi"
#     return f"{greeting}, {user_name}!"
#
# Parameter: str:0
#  Decide the language
# Parameter: str:1
#  Extract only the name provided
